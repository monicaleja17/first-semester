# %% [markdown]
# ## Redes

# %%
#importamos la libreria networkx que nos servira para la estructuracion de las redes y matplotlib para graficarla. 
import networkx as nx
import matplotlib.pyplot as plt

# %%
#invocamos nuestro archivo de texto 
n = open('rednacional.txt', "rb")

# %%
#lee el gráfico en formato de lista de adyacencia
G = nx.read_adjlist(n)

# %% [markdown]
# ## Red Nacional

# %%
G=nx.dodecahedral_graph()
nx.draw(G)
nx.draw(G,pos=nx.spring_layout(G), node_color='r', linewidths = 1.0, style='solid',font_size = 10, font_family = 'sans-serif', node_size = 400)
fig = plt.figure(figsize=(20.0,15.0))
plt.draw()

# %% [markdown]
# ## Red Territorial

# %%
t = open('redterritorial.txt', "rb")

# %%
G = nx.read_adjlist(t)

# %%
G=nx.dodecahedral_graph()
nx.draw(G)
nx.draw(G,pos=nx.spring_layout(G), node_color='y', linewidths = 1.0, style='solid',font_size = 10, font_family = 'sans-serif', node_size = 400);
fig = plt.figure(figsize=(20.0,15.0))
plt.draw()

# %% [markdown]
# ## Red Ejercito Nacional

# %%
e = open('redejercito.txt', "rb")

# %%
G = nx.read_adjlist(e)

# %%
G=nx.dodecahedral_graph()
nx.draw(G)
nx.draw(G,pos=nx.spring_layout(G), node_color='g', linewidths = 1.0, style='solid',font_size = 10, font_family = 'sans-serif', node_size = 400);
fig = plt.figure(figsize=(20.0,15.0))
plt.draw()
