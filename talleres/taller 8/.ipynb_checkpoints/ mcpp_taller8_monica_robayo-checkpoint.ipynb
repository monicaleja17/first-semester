# %% [markdown]
# # Taller 8
# Métodos Computacionales para Políticas Públicas - URosario
#
# **Entrega: viernes 17-abr-2020 11:59 PM**

# %% [markdown]
# <div class="alert alert-success">
#
# **[Monica Alejandra Robayo Gonzalez]** <br><br>
# [monica.robayo@urosario.edu.co]
# </div>

# %% [markdown]
# ## Instrucciones:
# - Guarde una copia de este *Jupyter Notebook* en su computador, idealmente en una carpeta destinada al material del curso.
# - Modifique el nombre del archivo del *notebook*, agregando al final un guión inferior y su nombre y apellido, separados estos últimos por otro guión inferior. Por ejemplo, mi *notebook* se llamaría: mcpp_taller8_santiago_matallana
# - Marque el *notebook* con su nombre y e-mail en el bloque verde arriba. Reemplace el texto "[Su nombre acá]" con su nombre y apellido. Similar para su e-mail.
# - Desarrolle la totalidad del taller sobre este *notebook*, insertando las celdas que sea necesario debajo de cada pregunta. Haga buen uso de las celdas para código y de las celdas tipo *markdown* según el caso.
# - Recuerde salvar periódicamente sus avances.
# - Cuando termine el taller:
#     1. Descárguelo en PDF. Si tiene algún problema con la conversión, descárguelo en HTML.
#     2. Suba todos los archivos a su repositorio en GitHub, en una carpeta destinada exclusivamente para este taller, antes de la fecha y hora límites.

# %% [markdown]
# ---

# %% [markdown]
# ### 1. [1 punto]
#
# Usando expresiones regulares extraiga en una lista todos los números presentes en el siguiente objeto de Python:
#
# ob1 = "JEFF BEZOS, the founder of Amazon, has reached a divorce settlement with his wife, MacKenzie. Mr Bezos will keep all the shares in the Washington Post and Blue Origin, a space-exploration firm, as well as 75% of the couple’s Amazon stock. Mrs Bezos will retain a 4% stake in the tech giant, worth nearly $36bn, which is likely to make her the third-richest woman alive when the divorce is finalised."

# %%
import re

# %%
ob1 = "JEFF BEZOS, the founder of Amazon, has reached a divorce settlement with his wife, MacKenzie. Mr Bezos will keep all the shares in the Washington Post and Blue Origin, a space-exploration firm, as well as 75% of the couple’s Amazon stock. Mrs Bezos will retain a 4% stake in the tech giant, worth nearly $36bn, which is likely to make her the third-richest woman alive when the divorce is finalised."
ob2 = re.findall('[0-9]+', ob1)
ob2
# Out:
# ['75', '4', '36']

# %% [markdown]
# ### 2. [1 punto]
#
# Usando expresiones regulares ahora extraiga de *ob1* sólo los números que correspondan a porcentajes.

# %%
ob3 = re.findall('[0-9]+%', ob1)
ob3
# Out:
# ['75%', '4%']

# %% [markdown]
# ### 3. [2 puntos]
#
# Usando expresiones regulares, escriba una función de Python que reciba una fecha en formato **Marzo 7, 2019** y retorne la fecha en formato **2019-07-03**

# %%
import re
import datetime

def current_date_format(date):
    dateSplitted = re.split('\W+', date)
    months = ["Enero", "Febrero", "Marzo", "Abri", "Mayo", "Junio", \
    "Julio", "Agosto", "Septiembre", "Octubre", "Noviembre", "Diciembre"]
     
    day = dateSplitted[1]
    month = months.index(dateSplitted[0]) + 1
    year = dateSplitted[2]
     
    formattedDate = datetime.datetime(int(year), int(month), int(day))
     
    messsage = formattedDate.strftime("%Y-%d-%m")
    return messsage

print (current_date_format( 'Marzo 7, 2019' ))
# Out:
# 2019-07-03

# %% [markdown]
# ### 4. [3 puntos]
#
# *ob2* es un string que reune una lista de clases en una universidad. Use expresiones regulares para extraer los códigos de cada una de las clases. Ejemplo: El código de la clase **COMPSCI 143 (Spring 2012): Machine Learning** es 143.
#
# ob2 = "COMPSCI 270 (Spring 2019): Introduction to Artificial Intelligence.
# COMPSCI 590.2 (Fall 2018): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design.
# COMPSCI 223 (Spring 2018): Computational Microeconomics.
# COMPSCI 570 (Fall 2017): Artificial Intelligence.
# COMPSCI 590.3 (Fall 2017) / 590.1 (Spring 2018): Ethics and AI.
# COMPSCI 590.2 (Spring 2017): Computation, Information, and Learning in Market Design.
# COMPSCI 590.4 (Spring 2016): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design.
# COMPSCI 290.4/590.4 (Spring 2015): Crowdsourcing Societal Tradeoffs.
# COMPSCI 570 (Fall 2014): Artificial Intelligence.
# COMPSCI 590.4 (Spring 2014): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design.
# COMPSCI 590.1 (Fall 2012): Linear and Integer Programming.
# COMPSCI 173 (Spring 2012): Computational Microeconomics.
# COMPSCI 296.1 (Fall 2011): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design.
# COMPSCI 296.1 (Fall 2010): Linear and Integer Programming.
# COMPSCI 173 (Spring 2010): Computational Microeconomics.
# COMPSCI 196.1/296.1 (Fall 2009): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design.
# COMPSCI 170 (Spring 2009): Introduction to Artificial Intelligence.
# COMPSCI 270 (Fall 2008): Artificial Intelligence.
# COMPSCI 196/296.2 (Spring 2008): Linear and Integer Programming.
# COMPSCI 196.2 (Fall 2007): Introduction to Computational Economics.
# COMPSCI 296.3 (Spring 2007): Topics in Computational Economics.
# COMPSCI 296.2 (Fall 2006): Computational Game Theory and Mechanism Design."

# %%
ob2 = "COMPSCI 270 (Spring 2019): Introduction to Artificial Intelligence. COMPSCI 590.2 (Fall 2018): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design. COMPSCI 223 (Spring 2018): Computational Microeconomics. COMPSCI 570 (Fall 2017): Artificial Intelligence. COMPSCI 590.3 (Fall 2017) / 590.1 (Spring 2018): Ethics and AI. COMPSCI 590.2 (Spring 2017): Computation, Information, and Learning in Market Design. COMPSCI 590.4 (Spring 2016): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design. COMPSCI 290.4/590.4 (Spring 2015): Crowdsourcing Societal Tradeoffs. COMPSCI 570 (Fall 2014): Artificial Intelligence. COMPSCI 590.4 (Spring 2014): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design. COMPSCI 590.1 (Fall 2012): Linear and Integer Programming. COMPSCI 173 (Spring 2012): Computational Microeconomics. COMPSCI 296.1 (Fall 2011): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design. COMPSCI 296.1 (Fall 2010): Linear and Integer Programming. COMPSCI 173 (Spring 2010): Computational Microeconomics. COMPSCI 196.1/296.1 (Fall 2009): Computational Microeconomics: Game Theory, Social Choice, and Mechanism Design. COMPSCI 170 (Spring 2009): Introduction to Artificial Intelligence. COMPSCI 270 (Fall 2008): Artificial Intelligence. COMPSCI 196/296.2 (Spring 2008): Linear and Integer Programming. COMPSCI 196.2 (Fall 2007): Introduction to Computational Economics. COMPSCI 296.3 (Spring 2007): Topics in Computational Economics. COMPSCI 296.2 (Fall 2006): Computational Game Theory and Mechanism Design."

# %%
cod = ('COMPSCI [0-9\.]+')

# %%
re.findall(cod, ob2)
# Out:
# ['COMPSCI 270',
#  'COMPSCI 590.2',
#  'COMPSCI 223',
#  'COMPSCI 570',
#  'COMPSCI 590.3',
#  'COMPSCI 590.2',
#  'COMPSCI 590.4',
#  'COMPSCI 290.4',
#  'COMPSCI 570',
#  'COMPSCI 590.4',
#  'COMPSCI 590.1',
#  'COMPSCI 173',
#  'COMPSCI 296.1',
#  'COMPSCI 296.1',
#  'COMPSCI 173',
#  'COMPSCI 196.1',
#  'COMPSCI 170',
#  'COMPSCI 270',
#  'COMPSCI 196',
#  'COMPSCI 196.2',
#  'COMPSCI 296.3',
#  'COMPSCI 296.2']

# %%
pat = ('[A-Z]+ [0-9./]+ \([\w]+ [0-9]*\): [\w a-z]+' )

# %%
re.findall(pat, ob2)
# Out:
# ['COMPSCI 270 (Spring 2019): Introduction to Artificial Intelligence',
#  'COMPSCI 590.2 (Fall 2018): Computational Microeconomics',
#  'COMPSCI 223 (Spring 2018): Computational Microeconomics',
#  'COMPSCI 570 (Fall 2017): Artificial Intelligence',
#  'COMPSCI 590.2 (Spring 2017): Computation',
#  'COMPSCI 590.4 (Spring 2016): Computational Microeconomics',
#  'COMPSCI 290.4/590.4 (Spring 2015): Crowdsourcing Societal Tradeoffs',
#  'COMPSCI 570 (Fall 2014): Artificial Intelligence',
#  'COMPSCI 590.4 (Spring 2014): Computational Microeconomics',
#  'COMPSCI 590.1 (Fall 2012): Linear and Integer Programming',
#  'COMPSCI 173 (Spring 2012): Computational Microeconomics',
#  'COMPSCI 296.1 (Fall 2011): Computational Microeconomics',
#  'COMPSCI 296.1 (Fall 2010): Linear and Integer Programming',
#  'COMPSCI 173 (Spring 2010): Computational Microeconomics',
#  'COMPSCI 196.1/296.1 (Fall 2009): Computational Microeconomics',
#  'COMPSCI 170 (Spring 2009): Introduction to Artificial Intelligence',
#  'COMPSCI 270 (Fall 2008): Artificial Intelligence',
#  'COMPSCI 196/296.2 (Spring 2008): Linear and Integer Programming',
#  'COMPSCI 196.2 (Fall 2007): Introduction to Computational Economics',
#  'COMPSCI 296.3 (Spring 2007): Topics in Computational Economics',
#  'COMPSCI 296.2 (Fall 2006): Computational Game Theory and Mechanism Design']

# %%
classes = re.findall( '[A-Z]+ [0-9./]+ \([\w]+ [0-9]*\): [\w a-z]+', str )

for s in classes:
    print( s, ' El codigo del curso es: ', re.findall('(?![A-Z]*\s)([0-9\.]+\/?[0-9\.]+)\s', s) )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-363-6f3af4bfcf1d> in <module>
# ----> 1 classes = re.findall( '[A-Z]+ [0-9./]+ \([\w]+ [0-9]*\): [\w a-z]+', str )
#       2
#       3 for s in classes:
#       4     print( s, ' El codigo del curso es: ', re.findall('(?![A-Z]*\s)([0-9\.]+\/?[0-9\.]+)\s', s) )
#
# ~\anaconda3\lib\re.py in findall(pattern, string, flags)
#     221
#     222     Empty matches are included in the result."""
# --> 223     return _compile(pattern, flags).findall(string)
#     224
#     225 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %% [markdown]
# ### 5. [5 puntos]
#
# *ob3* es un string que reune una lista de publicaciones. Use expresiones regulares para extraer todos los *Journals* en los cuales el autor ha publicado. Ejemplo: El paper **Bail, CA. "The configuration of symbolic boundaries against immigrants in Europe." American Sociological Review 73.1 (January 1, 2008): 37-59. Full Text** fue publicado en el Journal *American Sociological Review*
#
#  ob3 = "Bail, CA, Argyle, LP, Brown, TW, Bumpus, JP, Chen, H, Hunzaker, MBF, Lee, J, Mann, M, Merhout, F, and Volfovsky, A. \"Exposure to opposing views on social media can increase political polarization.\" Proceedings of the National Academy of Sciences of the United States of America 115.37 (September 2018): 9216-9221. Full Text Open Access Copy.\n",
#     "Bail, CA, Merhout, F, and Ding, P. \"Using Internet search data to examine the relationship between anti-Muslim and pro-ISIS sentiment in U.S. counties.\" Science Advances 4.6 (June 6, 2018): eaao5948-null. Full Text Open Access Copy.\n",
#     "Bail, CA, Brown, TW, and Mann, M. \"Channeling Hearts and Minds: Advocacy Organizations, Cognitive-Emotional Currents, and Public Conversation.\" American Sociological Review 82.6 (December 1, 2017): 1188-1213. Full Text.\n",
#     "Bail, CA. \"Taming Big Data: Using App Technology to Study Organizational Behavior on Social Media.\" Sociological Methods and Research 46.2 (March 1, 2017): 189-217. Full Text.\n",
#     "McDonnell, TE, Bail, CA, and Tavory, I. \"A Theory of Resonance.\" Sociological Theory 35.1 (March 1, 2017): 1-14. Full Text.\n",
#     "Bail, CA. \"Combining natural language processing and network analysis to examine how advocacy organizations stimulate conversation on social media.\" Proceedings of the National Academy of Sciences of the United States of America 113.42 (October 2016): 11823-11828. Full Text.\n",
#     "Bail, CA. \"Emotional Feedback and the Viral Spread of Social Media Messages About Autism Spectrum Disorders.\" American journal of public health 106.7 (July 2016): 1173-1180. Full Text.\n",
#     "Bail, CA. \"The public life of secrets: Deception, disclosure, and discursive framing in the policy process.\" Sociological Theory 33.2 (January 1, 2015): 97-124. Full Text.\n",
#     "Bail, CA. \"The cultural environment: Measuring culture with big data.\" Theory and Society 43.3 (January 1, 2014): 465-524. Full Text.\""

# %% [markdown]
# ### 6. [10 puntos]
#
#
# Vamos a hacer "scraping" a esta página: https://archive.ics.uci.edu/ml/datasets.php, que contiene un listado de 468 bases de datos que hacen parte del repositorio de la Universidad de California, Irvine.

# %% [markdown]
# Su tarea consiste en crear un "Pandas dataframe" que contenga 468 filas (una por base de datos) y las siguientes columnas:
# - Nombre de la base de datos
# - Link a la base de datos
# - Tipo de datos
# - Tipo de tarea a resolver (default task)
# - Tipo de las variables
# - Número de observaciones
# - Número de variables
# - Año
# - Descripción de la base (Pista: Utilice la opción list view: https://archive.ics.uci.edu/ml/datasets.php?format=&task=&att=&area=&numAtt=&numIns=&type=&sort=nameUp&view=list)

# %% [markdown]
# Diviértase.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
import re

# %%
base_url = "https://archive.ics.uci.edu/ml/datasets.php"

# %%
index_html = urlopen(base_url)
index_html

# %%
soup = BeautifulSoup(index_html, "lxml")

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE HTML>
# <html>
#  <body>
#   <p>
#    "-//W3C//DTD HTML 4.01 Transitional//EN\"&gt;
#   </p>
#   <title>
#    UCI Machine Learning Repository: Data Sets
#   </title>
#   <!-- Stylesheet link -->
#   <link href="assets/ml.css" rel="stylesheet" type="text/css"/>
#   <script language="JavaScript" type="text/javascript">
#    <!--
# function checkform ( form )
# {
#   // see http://www.thesitewizard.com/archive/validation.shtml
#   // for an explanation of this script and how to use it on your
#   // own website
#
#   // ** START **
#   if (form.q.value == "")
#   {
#     alert( "Please enter search terms." );
#     form.q.focus();
#     return false ;
#   }
#
#   if (getCheckedValue(form.sitesearch) == "ics.uci.edu" && form.q.value.indexOf("site:archive.ics.uci.edu/ml") == -1)
#   {
#     form.q.value = form.q.value + " site:archive.ics.uci.edu/ml";
#   }
#
#   // ** END **
#   return true ;
# }
#
# // return the value of the radio button that is checked
# // return an empty string if none are checked, or
# // there are no radio buttons
# function getCheckedValue(radioObj) {
# 	if(!radioObj)
# 		return "";
# 	var radioLength = radioObj.length;
# 	if(radioLength == undefined)
# 		if(radioObj.checked)
# 			return radioObj.value;
# 		else
# 			return "";
# 	for(var i = 0; i < radioLength; i++) {
# 		if(radioObj[i].checked) {
# 			return radioObj[i].value;
# 		}
# 	}
# 	return "";
# }
#
#
#
#
#
# //-->
#   </script>
#   <!-- SITE HEADER (INCLUDES LOGO AND SEARCH BOX) -->
#   <!-- SITE HEADER (INCLUDES LOGO AND SEARCH BOX) -->
#   <table bgcolor="#003366" width="100%">
#    <tr>
#     <td>
#      <span class="normal">
#       <a alt="Home" href="index.html">
#        <img border="0" src="assets/logo.gif"/>
#       </a>
#       <br/>
#       <a href="http://cml.ics.uci.edu">
#        <font color="FFDD33">
#         Center for Machine Learning and Intelligent Systems
#        </font>
#       </a>
#      </span>
#     </td>
#     <td align="right" valign="top" width="100%">
#      <span class="whitetext">
#       <a href="about.html">
#        About
#       </a>
#       <a href="citation_policy.html">
#        Citation Policy
#       </a>
#       <a href="donation_policy.html">
#        Donate a Data Set
#       </a>
#       <a href="contact.html">
#        Contact
#       </a>
#      </span>
#      <br/>
#      <br/>
#      <!-- Search Google -->
#      <form action="http://www.google.com/custom" method="GET" onsubmit="return checkform(this);">
#       <input maxlength="255" name="q" size="30" type="text" value=""/>
#       <input name="sa" type="submit" value="Search"/>
#       <input name="cof" type="hidden" value="AH:center;LH:130;L:http://archive.ics.uci.edu/assets/logo.gif;LW:384;AWFID:869c0b2eaa8d518e;"/>
#       <input name="domains" type="hidden" value="ics.uci.edu"/>
#       <br/>
#       <input checked="" name="sitesearch" type="radio" value="ics.uci.edu"/>
#       <span class="whitetext">
#        <font size="1">
#         Repository
#        </font>
#       </span>
#       <input name="sitesearch" type="radio" value=""/>
#       <span class="whitetext">
#        <font size="1">
#         Web
#        </font>
#       </span>
#       <a href="http://www.google.com/search">
#        <img align="middle" alt="Google" border="0" height="27" src="http://www.google.com/logos/Logo_25blk.gif"/>
#       </a>
#       <br/>
#      </form>
#      <!-- Search Google -->
#      <span class="whitetext">
#       <a href="datasets.php">
#        <font color="#FFDD33" size="3">
#         <b>
#          View ALL Data Sets
#         </b>
#        </font>
#       </a>
#      </span>
#      <br/>
#     </td>
#    </tr>
#   </table>
#   <br/>
#   <table cellpadding="3">
#    <tr>
#     <td valign="top">
#      <table>
#       <tr>
#        <td>
#         <p align="center" class="big">
#          Browse Through:
#         </p>
#        </td>
#       </tr>
#      </table>
#      <table border="2" cellpadding="2" width="150">
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           Default Task
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=&amp;task=cla&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Classification
#          </a>
#          <font color="red">
#           (366)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=reg&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Regression
#          </a>
#          <font color="red">
#           (112)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=clu&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Clustering
#          </a>
#          <font color="red">
#           (92)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=other&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Other
#          </a>
#          <font color="red">
#           (55)
#          </font>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           Attribute Type
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=&amp;task=&amp;att=cat&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Categorical
#          </a>
#          <font color="red">
#           (38)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=num&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Numerical
#          </a>
#          <font color="red">
#           (331)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=mix&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Mixed
#          </a>
#          <font color="red">
#           (55)
#          </font>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           Data Type
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=mvar&amp;sort=nameUp&amp;view=table">
#           Multivariate
#          </a>
#          <font color="red">
#           (383)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=uvar&amp;sort=nameUp&amp;view=table">
#           Univariate
#          </a>
#          <font color="red">
#           (24)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=seq&amp;sort=nameUp&amp;view=table">
#           Sequential
#          </a>
#          <font color="red">
#           (52)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=ts&amp;sort=nameUp&amp;view=table">
#           Time-Series
#          </a>
#          <font color="red">
#           (102)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=text&amp;sort=nameUp&amp;view=table">
#           Text
#          </a>
#          <font color="red">
#           (57)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=dt&amp;sort=nameUp&amp;view=table">
#           Domain-Theory
#          </a>
#          <font color="red">
#           (23)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=other&amp;sort=nameUp&amp;view=table">
#           Other
#          </a>
#          <font color="red">
#           (21)
#          </font>
#          <br/>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           Area
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=life&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Life Sciences
#          </a>
#          <font color="red">
#           (113)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=phys&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Physical Sciences
#          </a>
#          <font color="red">
#           (55)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=comp&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           CS / Engineering
#          </a>
#          <font color="red">
#           (179)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=soc&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Social Sciences
#          </a>
#          <font color="red">
#           (28)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=bus&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Business
#          </a>
#          <font color="red">
#           (32)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=game&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Game
#          </a>
#          <font color="red">
#           (10)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=other&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Other
#          </a>
#          <font color="red">
#           (75)
#          </font>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           # Attributes
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=less10&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Less than 10
#          </a>
#          <font color="red">
#           (122)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=10to100&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           10 to 100
#          </a>
#          <font color="red">
#           (223)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=greater100&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Greater than 100
#          </a>
#          <font color="red">
#           (90)
#          </font>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           # Instances
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=less100&amp;type=&amp;sort=nameUp&amp;view=table">
#           Less than 100
#          </a>
#          <font color="red">
#           (27)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=100to1000&amp;type=&amp;sort=nameUp&amp;view=table">
#           100 to 1000
#          </a>
#          <font color="red">
#           (169)
#          </font>
#          <br/>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=greater1000&amp;type=&amp;sort=nameUp&amp;view=table">
#           Greater than 1000
#          </a>
#          <font color="red">
#           (267)
#          </font>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td bgcolor="#003366">
#         <p class="whitetext">
#          <b>
#           Format Type
#          </b>
#         </p>
#        </td>
#       </tr>
#       <tr>
#        <td valign="top">
#         <p class="normal">
#          <a href="datasets.php?format=mat&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Matrix
#          </a>
#          <font color="red">
#           (347)
#          </font>
#          <br/>
#          <a href="datasets.php?format=nonmat&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">
#           Non-Matrix
#          </a>
#          <font color="red">
#           (150)
#          </font>
#         </p>
#        </td>
#       </tr>
#      </table>
#     </td>
#     <td valign="top">
#      <table width="100%">
#       <tr>
#        <td>
#         <p class="big">
#          <b>
#           497
#          </b>
#          Data Sets
#         </p>
#        </td>
#        <td align="right">
#         <p class="normal">
#          <font color="gray">
#           Table View
#          </font>
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=list">
#           List View
#          </a>
#         </p>
#        </td>
#       </tr>
#      </table>
#      <table border="1" cellpadding="5">
#       <tr bgcolor="#003366">
#        <td class="normal, whitetext">
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameDown&amp;view=table">
#           <b>
#            Name
#           </b>
#          </a>
#         </p>
#        </td>
#        <!-- <td><p class="normal, whitetext"><b>Abstract</b></p></td> -->
#        <td>
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=typeUp&amp;view=table">
#           <b>
#            Data Types
#           </b>
#          </a>
#         </p>
#        </td>
#        <td>
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=taskUp&amp;view=table">
#           <b>
#            Default Task
#           </b>
#          </a>
#         </p>
#        </td>
#        <td>
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=attTypeUp&amp;view=table">
#           <b>
#            Attribute Types
#           </b>
#          </a>
#         </p>
#        </td>
#        <td>
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=instUp&amp;view=table">
#           <b>
#            # Instances
#           </b>
#          </a>
#         </p>
#        </td>
#        <td>
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=attUp&amp;view=table">
#           <b>
#            # Attributes
#           </b>
#          </a>
#         </p>
#        </td>
#        <td>
#         <p class="normal, whitetext">
#          <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=dateUp&amp;view=table">
#           <b>
#            Year
#           </b>
#          </a>
#         </p>
#        </td>
#        <!-- <td><p class="normal, whitetext"><b>Area</b></p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Abalone">
#             <img border="1" src="assets/MLimages/SmallLarge1.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Abalone">
#               Abalone
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Predict the age of abalone from physical measurements&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          4177
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          8
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1995
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Adult">
#             <img border="1" src="assets/MLimages/SmallLarge2.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Adult">
#               Adult
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Predict whether income exceeds $50K/yr based on census data.  Also known as "Census Income" dataset.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          48842
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          14
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1996
#         </p>
#        </td>
#        <!-- <td><p class="normal">Social&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Annealing">
#             <img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Annealing">
#               Annealing
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Steel annealing data&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          798
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          38
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <!-- <td><p class="normal">Physical&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Anonymous+Microsoft+Web+Data">
#             <img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Anonymous+Microsoft+Web+Data">
#               Anonymous Microsoft Web Data
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Log of anonymous users of www.microsoft.com; predict areas of the web site a user visited based on data on other areas the user visited.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Recommender-Systems
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          37711
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          294
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1998
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Arrhythmia">
#             <img border="1" src="assets/MLimages/SmallLarge5.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Arrhythmia">
#               Arrhythmia
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Distinguish between the presence and absence of cardiac arrhythmia and classify it in one of the 16 groups.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          452
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          279
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1998
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Artificial+Characters">
#             <img border="1" src="assets/MLimages/SmallLarge6.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Artificial+Characters">
#               Artificial Characters
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Dataset artificially generated by using first order theory which describes structure of ten capital letters of English alphabet&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          6000
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          7
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1992
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Audiology+%28Original%29">
#             <img border="1" src="assets/MLimages/SmallLarge7.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Audiology+%28Original%29">
#               Audiology (Original)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Nominal audiology dataset from Baylor&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          226
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1987
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Audiology+%28Standardized%29">
#             <img border="1" src="assets/MLimages/SmallLarge7.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Audiology+%28Standardized%29">
#               Audiology (Standardized)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Standardized version of the original audiology database&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          226
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          69
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1992
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Auto+MPG">
#             <img border="1" src="assets/MLimages/SmallLarge9.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Auto+MPG">
#               Auto MPG
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Revised from CMU StatLib library, data concerns city-cycle fuel consumption&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Regression
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          398
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          8
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1993
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Automobile">
#             <img border="1" src="assets/MLimages/SmallLarge10.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Automobile">
#               Automobile
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">From 1985 Ward's Automotive Yearbook&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Regression
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          205
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          26
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1987
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Badges">
#             <img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Badges">
#               Badges
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Badges labeled with a "+" or "-" as a function of a person's name&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Univariate, Text
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          294
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1994
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Balance+Scale">
#             <img border="1" src="assets/MLimages/SmallLarge12.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Balance+Scale">
#               Balance Scale
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Balance scale weight & distance database&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          625
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          4
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1994
#         </p>
#        </td>
#        <!-- <td><p class="normal">Social&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Balloons">
#             <img border="1" src="assets/MLimages/SmallLarge13.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Balloons">
#               Balloons
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Data previously used in cognitive psychology experiment; 4 data sets represent different conditions of an experiment&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          16
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          4
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <!-- <td><p class="normal">Social&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Breast+Cancer">
#             <img border="1" src="assets/MLimages/SmallLarge14.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Breast+Cancer">
#               Breast Cancer
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Breast Cancer Data (Restricted Access)&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          286
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          9
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1988
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Breast+Cancer+Wisconsin+%28Original%29">
#             <img border="1" src="assets/MLimages/SmallLarge14.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Breast+Cancer+Wisconsin+%28Original%29">
#               Breast Cancer Wisconsin (Original)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Original Wisconsin Breast Cancer Database&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          699
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          10
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1992
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Breast+Cancer+Wisconsin+%28Prognostic%29">
#             <img border="1" src="assets/MLimages/SmallLarge14.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Breast+Cancer+Wisconsin+%28Prognostic%29">
#               Breast Cancer Wisconsin (Prognostic)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Prognostic Wisconsin Breast Cancer Database&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification, Regression
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          198
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          34
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1995
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29">
#             <img border="1" src="assets/MLimages/SmallLarge14.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29">
#               Breast Cancer Wisconsin (Diagnostic)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Diagnostic Wisconsin Breast Cancer Database&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          569
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          32
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1995
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Pittsburgh+Bridges">
#             <img border="1" src="assets/MLimages/SmallLarge18.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Pittsburgh+Bridges">
#               Pittsburgh Bridges
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Bridges database that has original and numeric-discretized datasets&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          108
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          13
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1990
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Car+Evaluation">
#             <img border="1" src="assets/MLimages/SmallLarge19.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Car+Evaluation">
#               Car Evaluation
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Derived from simple hierarchical decision model, this database may be useful for testing constructive induction and structure discovery methods.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1728
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          6
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1997
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Census+Income">
#             <img border="1" src="assets/MLimages/SmallLarge2.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Census+Income">
#               Census Income
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Predict whether income exceeds $50K/yr based on census data.  Also known as "Adult" dataset.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          48842
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          14
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1996
#         </p>
#        </td>
#        <!-- <td><p class="normal">Social&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Chess+%28King-Rook+vs.+King-Knight%29">
#             <img border="1" src="assets/MLimages/SmallLarge24.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Chess+%28King-Rook+vs.+King-Knight%29">
#               Chess (King-Rook vs. King-Knight)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Knight Pin Chess End-Game Database Creator&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate, Data-Generator
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          22
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1988
#         </p>
#        </td>
#        <!-- <td><p class="normal">Game&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Chess+%28King-Rook+vs.+King-Pawn%29">
#             <img border="1" src="assets/MLimages/SmallLarge24.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Chess+%28King-Rook+vs.+King-Pawn%29">
#               Chess (King-Rook vs. King-Pawn)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">King+Rook versus King+Pawn on a7 (usually abbreviated KRKPA7).&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          3196
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          36
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1989
#         </p>
#        </td>
#        <!-- <td><p class="normal">Game&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Chess+%28King-Rook+vs.+King%29">
#             <img border="1" src="assets/MLimages/SmallLarge24.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Chess+%28King-Rook+vs.+King%29">
#               Chess (King-Rook vs. King)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Chess Endgame Database for White King and Rook against Black King (KRK).&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          28056
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          6
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1994
#         </p>
#        </td>
#        <!-- <td><p class="normal">Game&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Chess+%28Domain+Theories%29">
#             <img border="1" src="assets/MLimages/SmallLarge24.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Chess+%28Domain+Theories%29">
#               Chess (Domain Theories)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">6 different domain theories for generating legal moves of chess&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Domain-Theory
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <!-- <td><p class="normal">Game&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Bach+Chorales">
#             <img border="1" src="assets/MLimages/SmallLarge25.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Bach+Chorales">
#               Bach Chorales
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Time-series data based on chorales; challenge is to learn generative grammar; data in Lisp&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Univariate, Time-Series
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          100
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          6
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Connect-4">
#             <img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Connect-4">
#               Connect-4
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Contains connect-4 positions&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate, Spatial
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          67557
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          42
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1995
#         </p>
#        </td>
#        <!-- <td><p class="normal">Game&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Credit+Approval">
#             <img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Credit+Approval">
#               Credit Approval
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">This data concerns credit card applications; good mix of attributes&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          690
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          15
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <!-- <td><p class="normal">Financial&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Japanese+Credit+Screening">
#             <img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Japanese+Credit+Screening">
#               Japanese Credit Screening
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Includes domain theory (generated by talking to Japanese domain experts); data in Lisp&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate, Domain-Theory
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
# ...
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2858
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          3
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2008
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Blood+Transfusion+Service+Center">
#             <img border="1" src="assets/MLimages/SmallLarge176.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Blood+Transfusion+Service+Center">
#               Blood Transfusion Service Center
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Data taken from the Blood Transfusion Service Center in Hsin-Chu City in Taiwan -- this is a classification problem. &nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          748
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          5
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2008
#         </p>
#        </td>
#        <!-- <td><p class="normal">Business&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/UJI+Pen+Characters+%28Version+2%29">
#             <img border="1" src="assets/MLimages/SmallLarge160.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/UJI+Pen+Characters+%28Version+2%29">
#               UJI Pen Characters (Version 2)
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">A pen-based database with more than 11k isolated handwritten characters&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate, Sequential
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          11640
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Semeion+Handwritten+Digit">
#             <img border="1" src="assets/MLimages/SmallLarge178.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Semeion+Handwritten+Digit">
#               Semeion Handwritten Digit
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">1593 handwritten digits from around 80 persons were scanned, stretched in a rectangular box 16x16 in a gray scale of 256 values.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1593
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          256
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2008
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/SECOM">
#             <img border="1" src="assets/MLimages/SmallLarge179.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/SECOM">
#               SECOM
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Data from a semi-conductor manufacturing process&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification, Causal-Discovery
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1567
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          591
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2008
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Plants">
#             <img border="1" src="assets/MLimages/SmallLarge180.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Plants">
#               Plants
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Data has been extracted from the USDA plants database. It contains all plants (species and genera) in the database and the states of USA and Canada where they occur.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Clustering
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          22632
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          70
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2008
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Libras+Movement">
#             <img border="1" src="assets/MLimages/SmallLarge181.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Libras+Movement">
#               Libras Movement
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">The data set contains 15 classes of 24 instances each. Each class references to a hand movement type in LIBRAS (Portuguese
# name 'LÍngua BRAsileira de Sinais', oficial brazilian signal language).&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate, Sequential
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification, Clustering
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          360
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          91
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Other&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Concrete+Slump+Test">
#             <img border="1" src="assets/MLimages/SmallLarge165.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Concrete+Slump+Test">
#               Concrete Slump Test
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Concrete is a highly complex material. The slump flow of concrete is not only determined by the water content, but that is also influenced by other concrete ingredients.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Regression
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          103
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          10
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Communities+and+Crime">
#             <img border="1" src="assets/MLimages/SmallLarge183.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Communities+and+Crime">
#               Communities and Crime
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Communities within the United States. The data combines socio-economic data from the 1990 US Census, law enforcement data from the 1990 US LEMAS survey, and crime data from the 1995 FBI UCR.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Regression
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          1994
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          128
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Social&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Acute+Inflammations">
#             <img border="1" src="assets/MLimages/SmallLarge184.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Acute+Inflammations">
#               Acute Inflammations
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">The data was created by a medical expert as a data set to test the expert system,
# which will perform the presumptive diagnosis of two diseases of the urinary system.
# &nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Categorical, Integer
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          120
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          6
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Wine+Quality">
#             <img border="1" src="assets/MLimages/SmallLarge186.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Wine+Quality">
#               Wine Quality
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Two datasets are included, related to red and white vinho verde wine samples, from the north of Portugal. The goal is to model wine quality based on physicochemical tests (see [Cortez et al., 2009], http://www3.dsi.uminho.pt/pcortez/wine/).&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification, Regression
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          4898
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          12
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Business&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/URL+Reputation">
#             <img border="1" src="assets/MLimages/SmallLarge187.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/URL+Reputation">
#               URL Reputation
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">Anonymized 120-day subset of the ICML-09 URL data containing 2.4 million examples and 3.2 million features.&nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate, Time-Series
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Integer, Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2396130
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          3231961
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2009
#         </p>
#        </td>
#        <!-- <td><p class="normal">Computer&nbsp;</p></td> -->
#       </tr>
#       <tr>
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/p53+Mutants">
#             <img border="1" src="assets/MLimages/SmallLarge188.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/p53+Mutants">
#               p53 Mutants
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#        <!-- <td><p class="normal">The goal is to model mutant p53 transcriptional activity (active vs inactive) based on data extracted from biophysical simulations.
# &nbsp;</p></td> -->
#        <td>
#         <p class="normal">
#          Multivariate
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Classification
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          Real
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          16772
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          5409
#         </p>
#        </td>
#        <td>
#         <p class="normal">
#          2010
#         </p>
#        </td>
#        <!-- <td><p class="normal">Life&nbsp;</p></td> -->
#       </tr>
#       <tr bgcolor="DDEEFF">
#        <td>
#         <table>
#          <tr>
#           <td>
#            <a href="datasets/Parkinsons+Telemonitoring">
#             <img border="1" src="assets/MLimages/SmallLarge174.jpg"/>
#            </a>
#           </td>
#           <td>
#            <p class="normal">
#             <b>
#              <a href="datasets/Parkinsons+Telemonitoring">
#               Parkinsons Telemonitoring
#              </a>
#             </b>
#            </p>
#           </td>
#          </tr>
#         </table>
#        </td>
#       </tr>
#      </table>
#     </td>
#    </tr>
#   </table>
#  </body>
# </html>

# %%
name=soup.find_all("b")

# %%
name=list(name)
print(name)
len(name)
# Out:
# [<b>View ALL Data Sets</b>, <b>Default Task</b>, <b>Attribute Type</b>, <b>Data Type</b>, <b>Area</b>, <b># Attributes</b>, <b># Instances</b>, <b>Format Type</b>, <b>497</b>, <b>Name</b>, <b>Data Types</b>, <b>Default Task</b>, <b>Attribute Types</b>, <b># Instances</b>, <b># Attributes</b>, <b>Year</b>, <b><a href="datasets/Abalone">Abalone</a></b>, <b><a href="datasets/Adult">Adult</a></b>, <b><a href="datasets/Annealing">Annealing</a></b>, <b><a href="datasets/Anonymous+Microsoft+Web+Data">Anonymous Microsoft Web Data</a></b>, <b><a href="datasets/Arrhythmia">Arrhythmia</a></b>, <b><a href="datasets/Artificial+Characters">Artificial Characters</a></b>, <b><a href="datasets/Audiology+%28Original%29">Audiology (Original)</a></b>, <b><a href="datasets/Audiology+%28Standardized%29">Audiology (Standardized)</a></b>, <b><a href="datasets/Auto+MPG">Auto MPG</a></b>, <b><a href="datasets/Automobile">Automobile</a></b>, <b><a href="datasets/Badges">Badges</a></b>, <b><a href="datasets/Balance+Scale">Balance Scale</a></b>, <b><a href="datasets/Balloons">Balloons</a></b>, <b><a href="datasets/Breast+Cancer">Breast Cancer</a></b>, <b><a href="datasets/Breast+Cancer+Wisconsin+%28Original%29">Breast Cancer Wisconsin (Original)</a></b>, <b><a href="datasets/Breast+Cancer+Wisconsin+%28Prognostic%29">Breast Cancer Wisconsin (Prognostic)</a></b>, <b><a href="datasets/Breast+Cancer+Wisconsin+%28Diagnostic%29">Breast Cancer Wisconsin (Diagnostic)</a></b>, <b><a href="datasets/Pittsburgh+Bridges">Pittsburgh Bridges</a></b>, <b><a href="datasets/Car+Evaluation">Car Evaluation</a></b>, <b><a href="datasets/Census+Income">Census Income</a></b>, <b><a href="datasets/Chess+%28King-Rook+vs.+King-Knight%29">Chess (King-Rook vs. King-Knight)</a></b>, <b><a href="datasets/Chess+%28King-Rook+vs.+King-Pawn%29">Chess (King-Rook vs. King-Pawn)</a></b>, <b><a href="datasets/Chess+%28King-Rook+vs.+King%29">Chess (King-Rook vs. King)</a></b>, <b><a href="datasets/Chess+%28Domain+Theories%29">Chess (Domain Theories)</a></b>, <b><a href="datasets/Bach+Chorales">Bach Chorales</a></b>, <b><a href="datasets/Connect-4">Connect-4</a></b>, <b><a href="datasets/Credit+Approval">Credit Approval</a></b>, <b><a href="datasets/Japanese+Credit+Screening">Japanese Credit Screening</a></b>, <b><a href="datasets/Computer+Hardware">Computer Hardware</a></b>, <b><a href="datasets/Contraceptive+Method+Choice">Contraceptive Method Choice</a></b>, <b><a href="datasets/Covertype">Covertype</a></b>, <b><a href="datasets/Cylinder+Bands">Cylinder Bands</a></b>, <b><a href="datasets/Dermatology">Dermatology</a></b>, <b><a href="datasets/Diabetes">Diabetes</a></b>, <b><a href="datasets/DGP2+-+The+Second+Data+Generation+Program">DGP2 - The Second Data Generation Program</a></b>, <b><a href="datasets/Document+Understanding">Document Understanding</a></b>, <b><a href="datasets/EBL+Domain+Theories">EBL Domain Theories</a></b>, <b><a href="datasets/Echocardiogram">Echocardiogram</a></b>, <b><a href="datasets/Ecoli">Ecoli</a></b>, <b><a href="datasets/Flags">Flags</a></b>, <b><a href="datasets/Function+Finding">Function Finding</a></b>, <b><a href="datasets/Glass+Identification">Glass Identification</a></b>, <b><a href="datasets/Haberman%27s+Survival">Haberman's Survival</a></b>, <b><a href="datasets/Hayes-Roth">Hayes-Roth</a></b>, <b><a href="datasets/Heart+Disease">Heart Disease</a></b>, <b><a href="datasets/Hepatitis">Hepatitis</a></b>, <b><a href="datasets/Horse+Colic">Horse Colic</a></b>, <b><a href="datasets/ICU">ICU</a></b>, <b><a href="datasets/Image+Segmentation">Image Segmentation</a></b>, <b><a href="datasets/Internet+Advertisements">Internet Advertisements</a></b>, <b><a href="datasets/Ionosphere">Ionosphere</a></b>, <b><a href="datasets/Iris">Iris</a></b>, <b><a href="datasets/ISOLET">ISOLET</a></b>, <b><a href="datasets/Kinship">Kinship</a></b>, <b><a href="datasets/Labor+Relations">Labor Relations</a></b>, <b><a href="datasets/LED+Display+Domain">LED Display Domain</a></b>, <b> ...
# 202

# %%
nombre=[0]*len(name)
for i in range(len(name)):
    name[i]=str(name[i])
    
    start=name[i].find("<a")+10
 
    end=name[i].find("</a>", start)
 
    nombre[i]=name[i][start:end]

# %%
nombre
# Out:
# ['LL Data Sets</b',
#  't Task</b',
#  'ute Type</b',
#  'ype</b',
#  'b',
#  'ibutes</b',
#  'ances</b',
#  ' Type</b',
#  '',
#  'b',
#  'ypes</b',
#  't Task</b',
#  'ute Types</b',
#  'ances</b',
#  'ibutes</b',
#  'b',
#  'atasets/Abalone">Abalone',
#  'atasets/Adult">Adult',
#  'atasets/Annealing">Annealing',
#  'atasets/Anonymous+Microsoft+Web+Data">Anonymous Microsoft Web Data',
#  'atasets/Arrhythmia">Arrhythmia',
#  'atasets/Artificial+Characters">Artificial Characters',
#  'atasets/Audiology+%28Original%29">Audiology (Original)',
#  'atasets/Audiology+%28Standardized%29">Audiology (Standardized)',
#  'atasets/Auto+MPG">Auto MPG',
#  'atasets/Automobile">Automobile',
#  'atasets/Badges">Badges',
#  'atasets/Balance+Scale">Balance Scale',
#  'atasets/Balloons">Balloons',
#  'atasets/Breast+Cancer">Breast Cancer',
#  'atasets/Breast+Cancer+Wisconsin+%28Original%29">Breast Cancer Wisconsin (Original)',
#  'atasets/Breast+Cancer+Wisconsin+%28Prognostic%29">Breast Cancer Wisconsin (Prognostic)',
#  'atasets/Breast+Cancer+Wisconsin+%28Diagnostic%29">Breast Cancer Wisconsin (Diagnostic)',
#  'atasets/Pittsburgh+Bridges">Pittsburgh Bridges',
#  'atasets/Car+Evaluation">Car Evaluation',
#  'atasets/Census+Income">Census Income',
#  'atasets/Chess+%28King-Rook+vs.+King-Knight%29">Chess (King-Rook vs. King-Knight)',
#  'atasets/Chess+%28King-Rook+vs.+King-Pawn%29">Chess (King-Rook vs. King-Pawn)',
#  'atasets/Chess+%28King-Rook+vs.+King%29">Chess (King-Rook vs. King)',
#  'atasets/Chess+%28Domain+Theories%29">Chess (Domain Theories)',
#  'atasets/Bach+Chorales">Bach Chorales',
#  'atasets/Connect-4">Connect-4',
#  'atasets/Credit+Approval">Credit Approval',
#  'atasets/Japanese+Credit+Screening">Japanese Credit Screening',
#  'atasets/Computer+Hardware">Computer Hardware',
#  'atasets/Contraceptive+Method+Choice">Contraceptive Method Choice',
#  'atasets/Covertype">Covertype',
#  'atasets/Cylinder+Bands">Cylinder Bands',
#  'atasets/Dermatology">Dermatology',
#  'atasets/Diabetes">Diabetes',
#  'atasets/DGP2+-+The+Second+Data+Generation+Program">DGP2 - The Second Data Generation Program',
#  'atasets/Document+Understanding">Document Understanding',
#  'atasets/EBL+Domain+Theories">EBL Domain Theories',
#  'atasets/Echocardiogram">Echocardiogram',
#  'atasets/Ecoli">Ecoli',
#  'atasets/Flags">Flags',
#  'atasets/Function+Finding">Function Finding',
#  'atasets/Glass+Identification">Glass Identification',
#  'atasets/Haberman%27s+Survival">Haberman\'s Survival',
#  'atasets/Hayes-Roth">Hayes-Roth',
#  'atasets/Heart+Disease">Heart Disease',
#  'atasets/Hepatitis">Hepatitis',
#  'atasets/Horse+Colic">Horse Colic',
#  'atasets/ICU">ICU',
#  'atasets/Image+Segmentation">Image Segmentation',
#  'atasets/Internet+Advertisements">Internet Advertisements',
#  'atasets/Ionosphere">Ionosphere',
#  'atasets/Iris">Iris',
#  'atasets/ISOLET">ISOLET',
#  'atasets/Kinship">Kinship',
#  'atasets/Labor+Relations">Labor Relations',
#  'atasets/LED+Display+Domain">LED Display Domain',
#  'atasets/Lenses">Lenses',
#  'atasets/Letter+Recognition">Letter Recognition',
#  'atasets/Liver+Disorders">Liver Disorders',
#  'atasets/Logic+Theorist">Logic Theorist',
#  'atasets/Lung+Cancer">Lung Cancer',
#  'atasets/Lymphography">Lymphography',
#  'atasets/Mechanical+Analysis">Mechanical Analysis',
#  'atasets/Meta-data">Meta-data',
#  'atasets/Mobile+Robots">Mobile Robots',
#  'atasets/Molecular+Biology+%28Promoter+Gene+Sequences%29">Molecular Biology (Promoter Gene Sequences)',
#  'atasets/Molecular+Biology+%28Protein+Secondary+Structure%29">Molecular Biology (Protein Secondary Structure)',
#  'atasets/Molecular+Biology+%28Splice-junction+Gene+Sequences%29">Molecular Biology (Splice-junction Gene Sequences)',
#  'atasets/MONK%27s+Problems">MONK\'s Problems',
#  'atasets/Moral+Reasoner">Moral Reasoner',
#  'atasets/Multiple+Features">Multiple Features',
#  'atasets/Mushroom">Mushroom',
#  'atasets/Musk+%28Version+1%29">Musk (Version 1)',
#  'atasets/Musk+%28Version+2%29">Musk (Version 2)',
#  'atasets/Nursery">Nursery',
#  'atasets/Othello+Domain+Theory">Othello Domain Theory',
#  'atasets/Page+Blocks+Classification">Page Blocks Classification',
#  'atasets/Optical+Recognition+of+Handwritten+Digits">Optical Recognition of Handwritten Digits',
#  'atasets/Pen-Based+Recognition+of+Handwritten+Digits">Pen-Based Recognition of Handwritten Digits',
#  'atasets/Post-Operative+Patient">Post-Operative Patient',
#  'atasets/Primary+Tumor">Primary Tumor',
#  'atasets/Prodigy">Prodigy',
#  'atasets/Qualitative+Structure+Activity+Relationships">Qualitative Structure Activity Relationships',
#  'atasets/Quadruped+Mammals">Quadruped Mammals',
#  'atasets/Servo">Servo',
#  'atasets/Shuttle+Landing+Control">Shuttle Landing Control',
#  'atasets/Solar+Flare">Solar Flare',
#  'atasets/Soybean+%28Large%29">Soybean (Large)',
#  'atasets/Soybean+%28Small%29">Soybean (Small)',
#  'atasets/Challenger+USA+Space+Shuttle+O-Ring">Challenger USA Space Shuttle O-Ring',
#  'atasets/Low+Resolution+Spectrometer">Low Resolution Spectrometer',
#  'atasets/Spambase">Spambase',
#  'atasets/SPECT+Heart">SPECT Heart',
#  'atasets/SPECTF+Heart">SPECTF Heart',
#  'atasets/Sponge">Sponge',
#  'atasets/Statlog+Project">Statlog Project',
#  'atasets/Student+Loan+Relational">Student Loan Relational',
#  'atasets/Teaching+Assistant+Evaluation">Teaching Assistant Evaluation',
#  'atasets/Tic-Tac-Toe+Endgame">Tic-Tac-Toe Endgame',
#  'atasets/Thyroid+Disease">Thyroid Disease',
#  'atasets/Trains">Trains',
#  'atasets/University">University',
#  'atasets/Congressional+Voting+Records">Congressional Voting Records',
#  'atasets/Water+Treatment+Plant">Water Treatment Plant',
#  'atasets/Waveform+Database+Generator+%28Version+1%29">Waveform Database Generator (Version 1)',
#  'atasets/Waveform+Database+Generator+%28Version+2%29">Waveform Database Generator (Version 2)',
#  'atasets/Wine">Wine',
#  'atasets/Yeast">Yeast',
#  'atasets/Zoo">Zoo',
#  'atasets/Undocumented">Undocumented',
#  'atasets/Twenty+Newsgroups">Twenty Newsgroups',
#  'atasets/Australian+Sign+Language+signs">Australian Sign Language signs',
#  'atasets/Australian+Sign+Language+signs+%28High+Quality%29">Australian Sign Language signs (High Quality)',
#  'atasets/US+Census+Data+%281990%29">US Census Data (1990)',
#  'atasets/Census-Income+%28KDD%29">Census-Income (KDD)',
#  'atasets/Coil+1999+Competition+Data">Coil 1999 Competition Data',
#  'atasets/Corel+Image+Features">Corel Image Features',
#  'atasets/E.+Coli+Genes">E. Coli Genes',
#  'atasets/EEG+Database">EEG Database',
#  'atasets/El+Nino">El Nino',
#  'atasets/Entree+Chicago+Recommendation+Data">Entree Chicago Recommendation Data',
#  'atasets/CMU+Face+Images">CMU Face Images',
#  'atasets/Insurance+Company+Benchmark+%28COIL+2000%29">Insurance Company Benchmark (COIL 2000)',
#  'atasets/Internet+Usage+Data">Internet Usage Data',
#  'atasets/IPUMS+Census+Database">IPUMS Census Database',
#  'atasets/Japanese+Vowels">Japanese Vowels',
#  'atasets/KDD+Cup+1998+Data">KDD Cup 1998 Data',
#  'atasets/KDD+Cup+1999+Data">KDD Cup 1999 Data',
#  'atasets/M.+Tuberculosis+Genes">M. Tuberculosis Genes',
#  'atasets/Movie">Movie',
#  'atasets/MSNBC.com+Anonymous+Web+Data">MSNBC.com Anonymous Web Data',
#  'atasets/NSF+Research+Award+Abstracts+1990-2003">NSF Research Award Abstracts 1990-2003',
#  'atasets/Pioneer-1+Mobile+Robot+Data">Pioneer-1 Mobile Robot Data',
#  'atasets/Pseudo+Periodic+Synthetic+Time+Series">Pseudo Periodic Synthetic Time Series',
#  'atasets/Reuters-21578+Text+Categorization+Collection">Reuters-21578 Text Categorization Collection',
#  'atasets/Robot+Execution+Failures">Robot Execution Failures',
#  'atasets/Synthetic+Control+Chart+Time+Series">Synthetic Control Chart Time Series',
#  'atasets/Syskill+and+Webert+Web+Page+Ratings">Syskill and Webert Web Page Ratings',
#  'atasets/UNIX+User+Data">UNIX User Data',
#  'atasets/Volcanoes+on+Venus+-+JARtool+experiment">Volcanoes on Venus - JARtool experiment',
#  'atasets/Statlog+%28Australian+Credit+Approval%29">Statlog (Australian Credit Approval)',
#  'atasets/Statlog+%28German+Credit+Data%29">Statlog (German Credit Data)',
#  'atasets/Statlog+%28Heart%29">Statlog (Heart)',
#  'atasets/Statlog+%28Landsat+Satellite%29">Statlog (Landsat Satellite)',
#  'atasets/Statlog+%28Image+Segmentation%29">Statlog (Image Segmentation)',
#  'atasets/Statlog+%28Shuttle%29">Statlog (Shuttle)',
#  'atasets/Statlog+%28Vehicle+Silhouettes%29">Statlog (Vehicle Silhouettes)',
#  'atasets/Connectionist+Bench+%28Nettalk+Corpus%29">Connectionist Bench (Nettalk Corpus)',
#  'atasets/Connectionist+Bench+%28Sonar%2C+Mines+vs.+Rocks%29">Connectionist Bench (Sonar, Mines vs. Rocks)',
#  'atasets/Connectionist+Bench+%28Vowel+Recognition+-+Deterding+Data%29">Connectionist Bench (Vowel Recognition - Deterding Data)',
#  'atasets/Economic+Sanctions">Economic Sanctions',
#  'atasets/Protein+Data">Protein Data',
#  'atasets/Cloud">Cloud',
#  'atasets/CalIt2+Building+People+Counts">CalIt2 Building People Counts',
#  'atasets/Dodgers+Loop+Sensor">Dodgers Loop Sensor',
#  'atasets/Poker+Hand">Poker Hand',
#  'atasets/MAGIC+Gamma+Telescope">MAGIC Gamma Telescope',
#  'atasets/UJI+Pen+Characters">UJI Pen Characters',
#  'atasets/Mammographic+Mass">Mammographic Mass',
#  'atasets/Forest+Fires">Forest Fires',
#  'atasets/Reuters+Transcribed+Subset">Reuters Transcribed Subset',
#  'atasets/Bag+of+Words">Bag of Words',
#  'atasets/Concrete+Compressive+Strength">Concrete Compressive Strength',
#  'atasets/Hill-Valley">Hill-Valley',
#  'atasets/Arcene">Arcene',
#  'atasets/Dexter">Dexter',
#  'atasets/Dorothea">Dorothea',
#  'atasets/Gisette">Gisette',
#  'atasets/Madelon">Madelon',
#  'atasets/Ozone+Level+Detection">Ozone Level Detection',
#  'atasets/Abscisic+Acid+Signaling+Network">Abscisic Acid Signaling Network',
#  'atasets/Parkinsons">Parkinsons',
#  'atasets/Character+Trajectories">Character Trajectories',
#  'atasets/Blood+Transfusion+Service+Center">Blood Transfusion Service Center',
#  'atasets/UJI+Pen+Characters+%28Version+2%29">UJI Pen Characters (Version 2)',
#  'atasets/Semeion+Handwritten+Digit">Semeion Handwritten Digit',
#  'atasets/SECOM">SECOM',
#  'atasets/Plants">Plants',
#  'atasets/Libras+Movement">Libras Movement',
#  'atasets/Concrete+Slump+Test">Concrete Slump Test',
#  'atasets/Communities+and+Crime">Communities and Crime',
#  'atasets/Acute+Inflammations">Acute Inflammations',
#  'atasets/Wine+Quality">Wine Quality',
#  'atasets/URL+Reputation">URL Reputation',
#  'atasets/p53+Mutants">p53 Mutants',
#  'atasets/Parkinsons+Telemonitoring">Parkinsons Telemonitoring']

# %%
dataTypes=soup.find_all("a")

# %%
dataTypes=list(dataTypes)
print(dataTypes)
len(dataTypes)
# Out:
# [<a alt="Home" href="index.html"><img border="0" src="assets/logo.gif"/></a>, <a href="http://cml.ics.uci.edu"><font color="FFDD33">Center for Machine Learning and Intelligent Systems</font></a>, <a href="about.html">About</a>, <a href="citation_policy.html">Citation Policy</a>, <a href="donation_policy.html">Donate a Data Set</a>, <a href="contact.html">Contact</a>, <a href="http://www.google.com/search"><img align="middle" alt="Google" border="0" height="27" src="http://www.google.com/logos/Logo_25blk.gif"/></a>, <a href="datasets.php"><font color="#FFDD33" size="3"><b>View ALL Data Sets</b></font></a>, <a href="datasets.php?format=&amp;task=cla&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Classification</a>, <a href="datasets.php?format=&amp;task=reg&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Regression</a>, <a href="datasets.php?format=&amp;task=clu&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Clustering</a>, <a href="datasets.php?format=&amp;task=other&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Other</a>, <a href="datasets.php?format=&amp;task=&amp;att=cat&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Categorical</a>, <a href="datasets.php?format=&amp;task=&amp;att=num&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Numerical</a>, <a href="datasets.php?format=&amp;task=&amp;att=mix&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Mixed</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=mvar&amp;sort=nameUp&amp;view=table">Multivariate</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=uvar&amp;sort=nameUp&amp;view=table">Univariate</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=seq&amp;sort=nameUp&amp;view=table">Sequential</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=ts&amp;sort=nameUp&amp;view=table">Time-Series</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=text&amp;sort=nameUp&amp;view=table">Text</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=dt&amp;sort=nameUp&amp;view=table">Domain-Theory</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=other&amp;sort=nameUp&amp;view=table">Other</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=life&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Life Sciences</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=phys&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Physical Sciences</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=comp&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">CS / Engineering</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=soc&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Social Sciences</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=bus&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Business</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=game&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Game</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=other&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Other</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=less10&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Less than 10</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=10to100&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">10 to 100</a>, <a href="datasets.php?format=&amp;task=&amp;att=&amp;area=& ...
# 417

# %%
nombreBase=[0]*len(dataTypes)
for i in range(len(dataTypes)):
    dataTypes[i]=str(dataTypes[i])
 
    start=dataTypes[i].find("<a")+10
 
    end=dataTypes[i].find("</a>", start)
 
    nombreBase[i]=dataTypes[i][start:end]

# %%
nombreBase
# Out:
# ['me" href="index.html"><img border="0" src="assets/logo.gif"/>',
#  'ttp://cml.ics.uci.edu"><font color="FFDD33">Center for Machine Learning and Intelligent Systems</font>',
#  'bout.html">About',
#  'itation_policy.html">Citation Policy',
#  'onation_policy.html">Donate a Data Set',
#  'ontact.html">Contact',
#  'ttp://www.google.com/search"><img align="middle" alt="Google" border="0" height="27" src="http://www.google.com/logos/Logo_25blk.gif"/>',
#  'atasets.php"><font color="#FFDD33" size="3"><b>View ALL Data Sets</b></font>',
#  'atasets.php?format=&amp;task=cla&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Classification',
#  'atasets.php?format=&amp;task=reg&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Regression',
#  'atasets.php?format=&amp;task=clu&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Clustering',
#  'atasets.php?format=&amp;task=other&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Other',
#  'atasets.php?format=&amp;task=&amp;att=cat&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Categorical',
#  'atasets.php?format=&amp;task=&amp;att=num&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Numerical',
#  'atasets.php?format=&amp;task=&amp;att=mix&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Mixed',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=mvar&amp;sort=nameUp&amp;view=table">Multivariate',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=uvar&amp;sort=nameUp&amp;view=table">Univariate',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=seq&amp;sort=nameUp&amp;view=table">Sequential',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=ts&amp;sort=nameUp&amp;view=table">Time-Series',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=text&amp;sort=nameUp&amp;view=table">Text',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=dt&amp;sort=nameUp&amp;view=table">Domain-Theory',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=other&amp;sort=nameUp&amp;view=table">Other',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=life&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Life Sciences',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=phys&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Physical Sciences',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=comp&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">CS / Engineering',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=soc&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Social Sciences',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=bus&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Business',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=game&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Game',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=other&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Other',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=less10&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Less than 10',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=10to100&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">10 to 100',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=greater100&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Greater than 100',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=less100&amp;type=&amp;sort=nameUp&amp;view=table">Less than 100',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=100to1000&amp;type=&amp;sort=nameUp&amp;view=table">100 to 1000',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=greater1000&amp;type=&amp;sort=nameUp&amp;view=table">Greater than 1000',
#  'atasets.php?format=mat&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Matrix',
#  'atasets.php?format=nonmat&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=table">Non-Matrix',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameUp&amp;view=list">List View',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=nameDown&amp;view=table"><b>Name</b>',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=typeUp&amp;view=table"><b>Data Types</b>',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=taskUp&amp;view=table"><b>Default Task</b>',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=attTypeUp&amp;view=table"><b>Attribute Types</b>',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=instUp&amp;view=table"><b># Instances</b>',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=attUp&amp;view=table"><b># Attributes</b>',
#  'atasets.php?format=&amp;task=&amp;att=&amp;area=&amp;numAtt=&amp;numIns=&amp;type=&amp;sort=dateUp&amp;view=table"><b>Year</b>',
#  'atasets/Abalone"><img border="1" src="assets/MLimages/SmallLarge1.jpg"/>',
#  'atasets/Abalone">Abalone',
#  'atasets/Adult"><img border="1" src="assets/MLimages/SmallLarge2.jpg"/>',
#  'atasets/Adult">Adult',
#  'atasets/Annealing"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Annealing">Annealing',
#  'atasets/Anonymous+Microsoft+Web+Data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Anonymous+Microsoft+Web+Data">Anonymous Microsoft Web Data',
#  'atasets/Arrhythmia"><img border="1" src="assets/MLimages/SmallLarge5.jpg"/>',
#  'atasets/Arrhythmia">Arrhythmia',
#  'atasets/Artificial+Characters"><img border="1" src="assets/MLimages/SmallLarge6.jpg"/>',
#  'atasets/Artificial+Characters">Artificial Characters',
#  'atasets/Audiology+%28Original%29"><img border="1" src="assets/MLimages/SmallLarge7.jpg"/>',
#  'atasets/Audiology+%28Original%29">Audiology (Original)',
#  'atasets/Audiology+%28Standardized%29"><img border="1" src="assets/MLimages/SmallLarge7.jpg"/>',
#  'atasets/Audiology+%28Standardized%29">Audiology (Standardized)',
#  'atasets/Auto+MPG"><img border="1" src="assets/MLimages/SmallLarge9.jpg"/>',
#  'atasets/Auto+MPG">Auto MPG',
#  'atasets/Automobile"><img border="1" src="assets/MLimages/SmallLarge10.jpg"/>',
#  'atasets/Automobile">Automobile',
#  'atasets/Badges"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Badges">Badges',
#  'atasets/Balance+Scale"><img border="1" src="assets/MLimages/SmallLarge12.jpg"/>',
#  'atasets/Balance+Scale">Balance Scale',
#  'atasets/Balloons"><img border="1" src="assets/MLimages/SmallLarge13.jpg"/>',
#  'atasets/Balloons">Balloons',
#  'atasets/Breast+Cancer"><img border="1" src="assets/MLimages/SmallLarge14.jpg"/>',
#  'atasets/Breast+Cancer">Breast Cancer',
#  'atasets/Breast+Cancer+Wisconsin+%28Original%29"><img border="1" src="assets/MLimages/SmallLarge14.jpg"/>',
#  'atasets/Breast+Cancer+Wisconsin+%28Original%29">Breast Cancer Wisconsin (Original)',
#  'atasets/Breast+Cancer+Wisconsin+%28Prognostic%29"><img border="1" src="assets/MLimages/SmallLarge14.jpg"/>',
#  'atasets/Breast+Cancer+Wisconsin+%28Prognostic%29">Breast Cancer Wisconsin (Prognostic)',
#  'atasets/Breast+Cancer+Wisconsin+%28Diagnostic%29"><img border="1" src="assets/MLimages/SmallLarge14.jpg"/>',
#  'atasets/Breast+Cancer+Wisconsin+%28Diagnostic%29">Breast Cancer Wisconsin (Diagnostic)',
#  'atasets/Pittsburgh+Bridges"><img border="1" src="assets/MLimages/SmallLarge18.jpg"/>',
#  'atasets/Pittsburgh+Bridges">Pittsburgh Bridges',
#  'atasets/Car+Evaluation"><img border="1" src="assets/MLimages/SmallLarge19.jpg"/>',
#  'atasets/Car+Evaluation">Car Evaluation',
#  'atasets/Census+Income"><img border="1" src="assets/MLimages/SmallLarge2.jpg"/>',
#  'atasets/Census+Income">Census Income',
#  'atasets/Chess+%28King-Rook+vs.+King-Knight%29"><img border="1" src="assets/MLimages/SmallLarge24.jpg"/>',
#  'atasets/Chess+%28King-Rook+vs.+King-Knight%29">Chess (King-Rook vs. King-Knight)',
#  'atasets/Chess+%28King-Rook+vs.+King-Pawn%29"><img border="1" src="assets/MLimages/SmallLarge24.jpg"/>',
#  'atasets/Chess+%28King-Rook+vs.+King-Pawn%29">Chess (King-Rook vs. King-Pawn)',
#  'atasets/Chess+%28King-Rook+vs.+King%29"><img border="1" src="assets/MLimages/SmallLarge24.jpg"/>',
#  'atasets/Chess+%28King-Rook+vs.+King%29">Chess (King-Rook vs. King)',
#  'atasets/Chess+%28Domain+Theories%29"><img border="1" src="assets/MLimages/SmallLarge24.jpg"/>',
#  'atasets/Chess+%28Domain+Theories%29">Chess (Domain Theories)',
#  'atasets/Bach+Chorales"><img border="1" src="assets/MLimages/SmallLarge25.jpg"/>',
#  'atasets/Bach+Chorales">Bach Chorales',
#  'atasets/Connect-4"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Connect-4">Connect-4',
#  'atasets/Credit+Approval"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Credit+Approval">Credit Approval',
#  'atasets/Japanese+Credit+Screening"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Japanese+Credit+Screening">Japanese Credit Screening',
#  'atasets/Computer+Hardware"><img border="1" src="assets/MLimages/SmallLarge29.jpg"/>',
#  'atasets/Computer+Hardware">Computer Hardware',
#  'atasets/Contraceptive+Method+Choice"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Contraceptive+Method+Choice">Contraceptive Method Choice',
#  'atasets/Covertype"><img border="1" src="assets/MLimages/SmallLarge31.jpg"/>',
#  'atasets/Covertype">Covertype',
#  'atasets/Cylinder+Bands"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Cylinder+Bands">Cylinder Bands',
#  'atasets/Dermatology"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Dermatology">Dermatology',
#  'atasets/Diabetes"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Diabetes">Diabetes',
#  'atasets/DGP2+-+The+Second+Data+Generation+Program"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/DGP2+-+The+Second+Data+Generation+Program">DGP2 - The Second Data Generation Program',
#  'atasets/Document+Understanding"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Document+Understanding">Document Understanding',
#  'atasets/EBL+Domain+Theories"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/EBL+Domain+Theories">EBL Domain Theories',
#  'atasets/Echocardiogram"><img border="1" src="assets/MLimages/SmallLarge38.jpg"/>',
#  'atasets/Echocardiogram">Echocardiogram',
#  'atasets/Ecoli"><img border="1" src="assets/MLimages/SmallLarge120.jpg"/>',
#  'atasets/Ecoli">Ecoli',
#  'atasets/Flags"><img border="1" src="assets/MLimages/SmallLarge40.jpg"/>',
#  'atasets/Flags">Flags',
#  'atasets/Function+Finding"><img border="1" src="assets/MLimages/SmallLarge41.jpg"/>',
#  'atasets/Function+Finding">Function Finding',
#  'atasets/Glass+Identification"><img border="1" src="assets/MLimages/SmallLarge42.jpg"/>',
#  'atasets/Glass+Identification">Glass Identification',
#  'atasets/Haberman%27s+Survival"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Haberman%27s+Survival">Haberman\'s Survival',
#  'atasets/Hayes-Roth"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Hayes-Roth">Hayes-Roth',
#  'atasets/Heart+Disease"><img border="1" src="assets/MLimages/SmallLarge45.jpg"/>',
#  'atasets/Heart+Disease">Heart Disease',
#  'atasets/Hepatitis"><img border="1" src="assets/MLimages/SmallLarge46.jpg"/>',
#  'atasets/Hepatitis">Hepatitis',
#  'atasets/Horse+Colic"><img border="1" src="assets/MLimages/SmallLarge47.jpg"/>',
#  'atasets/Horse+Colic">Horse Colic',
#  'atasets/ICU"><img border="1" src="assets/MLimages/SmallLarge49.jpg"/>',
#  'atasets/ICU">ICU',
#  'atasets/Image+Segmentation"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Image+Segmentation">Image Segmentation',
#  'atasets/Internet+Advertisements"><img border="1" src="assets/MLimages/SmallLarge51.jpg"/>',
#  'atasets/Internet+Advertisements">Internet Advertisements',
#  'atasets/Ionosphere"><img border="1" src="assets/MLimages/SmallLarge52.jpg"/>',
#  'atasets/Ionosphere">Ionosphere',
#  'atasets/Iris"><img border="1" src="assets/MLimages/SmallLarge53.jpg"/>',
#  'atasets/Iris">Iris',
#  'atasets/ISOLET"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/ISOLET">ISOLET',
#  'atasets/Kinship"><img border="1" src="assets/MLimages/SmallLarge55.jpg"/>',
#  'atasets/Kinship">Kinship',
#  'atasets/Labor+Relations"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Labor+Relations">Labor Relations',
#  'atasets/LED+Display+Domain"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/LED+Display+Domain">LED Display Domain',
#  'atasets/Lenses"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Lenses">Lenses',
#  'atasets/Letter+Recognition"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Letter+Recognition">Letter Recognition',
#  'atasets/Liver+Disorders"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Liver+Disorders">Liver Disorders',
#  'atasets/Logic+Theorist"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Logic+Theorist">Logic Theorist',
#  'atasets/Lung+Cancer"><img border="1" src="assets/MLimages/SmallLarge62.jpg"/>',
#  'atasets/Lung+Cancer">Lung Cancer',
#  'atasets/Lymphography"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Lymphography">Lymphography',
#  'atasets/Mechanical+Analysis"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Mechanical+Analysis">Mechanical Analysis',
#  'atasets/Meta-data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Meta-data">Meta-data',
#  'atasets/Mobile+Robots"><img border="1" src="assets/MLimages/SmallLarge66.jpg"/>',
#  'atasets/Mobile+Robots">Mobile Robots',
#  'atasets/Molecular+Biology+%28Promoter+Gene+Sequences%29"><img border="1" src="assets/MLimages/SmallLarge67.jpg"/>',
#  'atasets/Molecular+Biology+%28Promoter+Gene+Sequences%29">Molecular Biology (Promoter Gene Sequences)',
#  'atasets/Molecular+Biology+%28Protein+Secondary+Structure%29"><img border="1" src="assets/MLimages/SmallLarge67.jpg"/>',
#  'atasets/Molecular+Biology+%28Protein+Secondary+Structure%29">Molecular Biology (Protein Secondary Structure)',
#  'atasets/Molecular+Biology+%28Splice-junction+Gene+Sequences%29"><img border="1" src="assets/MLimages/SmallLarge67.jpg"/>',
#  'atasets/Molecular+Biology+%28Splice-junction+Gene+Sequences%29">Molecular Biology (Splice-junction Gene Sequences)',
#  'atasets/MONK%27s+Problems"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/MONK%27s+Problems">MONK\'s Problems',
#  'atasets/Moral+Reasoner"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Moral+Reasoner">Moral Reasoner',
#  'atasets/Multiple+Features"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Multiple+Features">Multiple Features',
#  'atasets/Mushroom"><img border="1" src="assets/MLimages/SmallLarge73.jpg"/>',
#  'atasets/Mushroom">Mushroom',
#  'atasets/Musk+%28Version+1%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Musk+%28Version+1%29">Musk (Version 1)',
#  'atasets/Musk+%28Version+2%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Musk+%28Version+2%29">Musk (Version 2)',
#  'atasets/Nursery"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Nursery">Nursery',
#  'atasets/Othello+Domain+Theory"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Othello+Domain+Theory">Othello Domain Theory',
#  'atasets/Page+Blocks+Classification"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Page+Blocks+Classification">Page Blocks Classification',
#  'atasets/Optical+Recognition+of+Handwritten+Digits"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Optical+Recognition+of+Handwritten+Digits">Optical Recognition of Handwritten Digits',
#  'atasets/Pen-Based+Recognition+of+Handwritten+Digits"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Pen-Based+Recognition+of+Handwritten+Digits">Pen-Based Recognition of Handwritten Digits',
#  'atasets/Post-Operative+Patient"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Post-Operative+Patient">Post-Operative Patient',
#  'atasets/Primary+Tumor"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Primary+Tumor">Primary Tumor',
#  'atasets/Prodigy"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Prodigy">Prodigy',
#  'atasets/Qualitative+Structure+Activity+Relationships"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Qualitative+Structure+Activity+Relationships">Qualitative Structure Activity Relationships',
#  'atasets/Quadruped+Mammals"><img border="1" src="assets/MLimages/SmallLarge86.jpg"/>',
#  'atasets/Quadruped+Mammals">Quadruped Mammals',
#  'atasets/Servo"><img border="1" src="assets/MLimages/SmallLarge87.jpg"/>',
#  'atasets/Servo">Servo',
#  'atasets/Shuttle+Landing+Control"><img border="1" src="assets/MLimages/SmallLarge92.jpg"/>',
#  'atasets/Shuttle+Landing+Control">Shuttle Landing Control',
#  'atasets/Solar+Flare"><img border="1" src="assets/MLimages/SmallLarge89.jpg"/>',
#  'atasets/Solar+Flare">Solar Flare',
#  'atasets/Soybean+%28Large%29"><img border="1" src="assets/MLimages/SmallLarge90.jpg"/>',
#  'atasets/Soybean+%28Large%29">Soybean (Large)',
#  'atasets/Soybean+%28Small%29"><img border="1" src="assets/MLimages/SmallLarge90.jpg"/>',
#  'atasets/Soybean+%28Small%29">Soybean (Small)',
#  'atasets/Challenger+USA+Space+Shuttle+O-Ring"><img border="1" src="assets/MLimages/SmallLarge92.jpg"/>',
#  'atasets/Challenger+USA+Space+Shuttle+O-Ring">Challenger USA Space Shuttle O-Ring',
#  'atasets/Low+Resolution+Spectrometer"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Low+Resolution+Spectrometer">Low Resolution Spectrometer',
#  'atasets/Spambase"><img border="1" src="assets/MLimages/SmallLarge94.jpg"/>',
#  'atasets/Spambase">Spambase',
#  'atasets/SPECT+Heart"><img border="1" src="assets/MLimages/SmallLarge45.jpg"/>',
#  'atasets/SPECT+Heart">SPECT Heart',
#  'atasets/SPECTF+Heart"><img border="1" src="assets/MLimages/SmallLarge45.jpg"/>',
#  'atasets/SPECTF+Heart">SPECTF Heart',
#  'atasets/Sponge"><img border="1" src="assets/MLimages/SmallLarge97.jpg"/>',
#  'atasets/Sponge">Sponge',
#  'atasets/Statlog+Project"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Statlog+Project">Statlog Project',
#  'atasets/Student+Loan+Relational"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Student+Loan+Relational">Student Loan Relational',
#  'atasets/Teaching+Assistant+Evaluation"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Teaching+Assistant+Evaluation">Teaching Assistant Evaluation',
#  'atasets/Tic-Tac-Toe+Endgame"><img border="1" src="assets/MLimages/SmallLarge101.jpg"/>',
#  'atasets/Tic-Tac-Toe+Endgame">Tic-Tac-Toe Endgame',
#  'atasets/Thyroid+Disease"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Thyroid+Disease">Thyroid Disease',
#  'atasets/Trains"><img border="1" src="assets/MLimages/SmallLarge103.jpg"/>',
#  'atasets/Trains">Trains',
#  'atasets/University"><img border="1" src="assets/MLimages/SmallLarge104.jpg"/>',
#  'atasets/University">University',
#  'atasets/Congressional+Voting+Records"><img border="1" src="assets/MLimages/SmallLarge105.jpg"/>',
#  'atasets/Congressional+Voting+Records">Congressional Voting Records',
#  'atasets/Water+Treatment+Plant"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Water+Treatment+Plant">Water Treatment Plant',
#  'atasets/Waveform+Database+Generator+%28Version+1%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Waveform+Database+Generator+%28Version+1%29">Waveform Database Generator (Version 1)',
#  'atasets/Waveform+Database+Generator+%28Version+2%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Waveform+Database+Generator+%28Version+2%29">Waveform Database Generator (Version 2)',
#  'atasets/Wine"><img border="1" src="assets/MLimages/SmallLarge109.jpg"/>',
#  'atasets/Wine">Wine',
#  'atasets/Yeast"><img border="1" src="assets/MLimages/SmallLarge110.jpg"/>',
#  'atasets/Yeast">Yeast',
#  'atasets/Zoo"><img border="1" src="assets/MLimages/SmallLarge111.jpg"/>',
#  'atasets/Zoo">Zoo',
#  'atasets/Undocumented"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Undocumented">Undocumented',
#  'atasets/Twenty+Newsgroups"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Twenty+Newsgroups">Twenty Newsgroups',
#  'atasets/Australian+Sign+Language+signs"><img border="1" src="assets/MLimages/SmallLarge114.jpg"/>',
#  'atasets/Australian+Sign+Language+signs">Australian Sign Language signs',
#  'atasets/Australian+Sign+Language+signs+%28High+Quality%29"><img border="1" src="assets/MLimages/SmallLarge114.jpg"/>',
#  'atasets/Australian+Sign+Language+signs+%28High+Quality%29">Australian Sign Language signs (High Quality)',
#  'atasets/US+Census+Data+%281990%29"><img border="1" src="assets/MLimages/SmallLarge2.jpg"/>',
#  'atasets/US+Census+Data+%281990%29">US Census Data (1990)',
#  'atasets/Census-Income+%28KDD%29"><img border="1" src="assets/MLimages/SmallLarge2.jpg"/>',
#  'atasets/Census-Income+%28KDD%29">Census-Income (KDD)',
#  'atasets/Coil+1999+Competition+Data"><img border="1" src="assets/MLimages/SmallLarge118.jpg"/>',
#  'atasets/Coil+1999+Competition+Data">Coil 1999 Competition Data',
#  'atasets/Corel+Image+Features"><img border="1" src="assets/MLimages/SmallLarge119.jpg"/>',
#  'atasets/Corel+Image+Features">Corel Image Features',
#  'atasets/E.+Coli+Genes"><img border="1" src="assets/MLimages/SmallLarge120.jpg"/>',
#  'atasets/E.+Coli+Genes">E. Coli Genes',
#  'atasets/EEG+Database"><img border="1" src="assets/MLimages/SmallLarge121.jpg"/>',
#  'atasets/EEG+Database">EEG Database',
#  'atasets/El+Nino"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/El+Nino">El Nino',
#  'atasets/Entree+Chicago+Recommendation+Data"><img border="1" src="assets/MLimages/SmallLarge123.jpg"/>',
#  'atasets/Entree+Chicago+Recommendation+Data">Entree Chicago Recommendation Data',
#  'atasets/CMU+Face+Images"><img border="1" src="assets/MLimages/SmallLarge124.jpg"/>',
#  'atasets/CMU+Face+Images">CMU Face Images',
#  'atasets/Insurance+Company+Benchmark+%28COIL+2000%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Insurance+Company+Benchmark+%28COIL+2000%29">Insurance Company Benchmark (COIL 2000)',
#  'atasets/Internet+Usage+Data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Internet+Usage+Data">Internet Usage Data',
#  'atasets/IPUMS+Census+Database"><img border="1" src="assets/MLimages/SmallLarge2.jpg"/>',
#  'atasets/IPUMS+Census+Database">IPUMS Census Database',
#  'atasets/Japanese+Vowels"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Japanese+Vowels">Japanese Vowels',
#  'atasets/KDD+Cup+1998+Data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/KDD+Cup+1998+Data">KDD Cup 1998 Data',
#  'atasets/KDD+Cup+1999+Data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/KDD+Cup+1999+Data">KDD Cup 1999 Data',
#  'atasets/M.+Tuberculosis+Genes"><img border="1" src="assets/MLimages/SmallLarge131.jpg"/>',
#  'atasets/M.+Tuberculosis+Genes">M. Tuberculosis Genes',
#  'atasets/Movie"><img border="1" src="assets/MLimages/SmallLarge132.jpg"/>',
#  'atasets/Movie">Movie',
#  'atasets/MSNBC.com+Anonymous+Web+Data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/MSNBC.com+Anonymous+Web+Data">MSNBC.com Anonymous Web Data',
#  'atasets/NSF+Research+Award+Abstracts+1990-2003"><img border="1" src="assets/MLimages/SmallLarge134.jpg"/>',
#  'atasets/NSF+Research+Award+Abstracts+1990-2003">NSF Research Award Abstracts 1990-2003',
#  'atasets/Pioneer-1+Mobile+Robot+Data"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Pioneer-1+Mobile+Robot+Data">Pioneer-1 Mobile Robot Data',
#  'atasets/Pseudo+Periodic+Synthetic+Time+Series"><img border="1" src="assets/MLimages/SmallLarge136.jpg"/>',
#  'atasets/Pseudo+Periodic+Synthetic+Time+Series">Pseudo Periodic Synthetic Time Series',
#  'atasets/Reuters-21578+Text+Categorization+Collection"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Reuters-21578+Text+Categorization+Collection">Reuters-21578 Text Categorization Collection',
#  'atasets/Robot+Execution+Failures"><img border="1" src="assets/MLimages/SmallLarge138.jpg"/>',
#  'atasets/Robot+Execution+Failures">Robot Execution Failures',
#  'atasets/Synthetic+Control+Chart+Time+Series"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Synthetic+Control+Chart+Time+Series">Synthetic Control Chart Time Series',
#  'atasets/Syskill+and+Webert+Web+Page+Ratings"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Syskill+and+Webert+Web+Page+Ratings">Syskill and Webert Web Page Ratings',
#  'atasets/UNIX+User+Data"><img border="1" src="assets/MLimages/SmallLarge141.jpg"/>',
#  'atasets/UNIX+User+Data">UNIX User Data',
#  'atasets/Volcanoes+on+Venus+-+JARtool+experiment"><img border="1" src="assets/MLimages/SmallLarge142.jpg"/>',
#  'atasets/Volcanoes+on+Venus+-+JARtool+experiment">Volcanoes on Venus - JARtool experiment',
#  'atasets/Statlog+%28Australian+Credit+Approval%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Statlog+%28Australian+Credit+Approval%29">Statlog (Australian Credit Approval)',
#  'atasets/Statlog+%28German+Credit+Data%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Statlog+%28German+Credit+Data%29">Statlog (German Credit Data)',
#  'atasets/Statlog+%28Heart%29"><img border="1" src="assets/MLimages/SmallLarge45.jpg"/>',
#  'atasets/Statlog+%28Heart%29">Statlog (Heart)',
#  'atasets/Statlog+%28Landsat+Satellite%29"><img border="1" src="assets/MLimages/SmallLarge146.jpg"/>',
#  'atasets/Statlog+%28Landsat+Satellite%29">Statlog (Landsat Satellite)',
#  'atasets/Statlog+%28Image+Segmentation%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Statlog+%28Image+Segmentation%29">Statlog (Image Segmentation)',
#  'atasets/Statlog+%28Shuttle%29"><img border="1" src="assets/MLimages/SmallLarge92.jpg"/>',
#  'atasets/Statlog+%28Shuttle%29">Statlog (Shuttle)',
#  'atasets/Statlog+%28Vehicle+Silhouettes%29"><img border="1" src="assets/MLimages/SmallLarge149.jpg"/>',
#  'atasets/Statlog+%28Vehicle+Silhouettes%29">Statlog (Vehicle Silhouettes)',
#  'atasets/Connectionist+Bench+%28Nettalk+Corpus%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Connectionist+Bench+%28Nettalk+Corpus%29">Connectionist Bench (Nettalk Corpus)',
#  'atasets/Connectionist+Bench+%28Sonar%2C+Mines+vs.+Rocks%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Connectionist+Bench+%28Sonar%2C+Mines+vs.+Rocks%29">Connectionist Bench (Sonar, Mines vs. Rocks)',
#  'atasets/Connectionist+Bench+%28Vowel+Recognition+-+Deterding+Data%29"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Connectionist+Bench+%28Vowel+Recognition+-+Deterding+Data%29">Connectionist Bench (Vowel Recognition - Deterding Data)',
#  'atasets/Economic+Sanctions"><img border="1" src="assets/MLimages/SmallLarge153.jpg"/>',
#  'atasets/Economic+Sanctions">Economic Sanctions',
#  'atasets/Protein+Data"><img border="1" src="assets/MLimages/SmallLarge154.jpg"/>',
#  'atasets/Protein+Data">Protein Data',
#  'atasets/Cloud"><img border="1" src="assets/MLimages/SmallLarge155.jpg"/>',
#  'atasets/Cloud">Cloud',
#  'atasets/CalIt2+Building+People+Counts"><img border="1" src="assets/MLimages/SmallLarge156.jpg"/>',
#  'atasets/CalIt2+Building+People+Counts">CalIt2 Building People Counts',
#  'atasets/Dodgers+Loop+Sensor"><img border="1" src="assets/MLimages/SmallLarge157.jpg"/>',
#  'atasets/Dodgers+Loop+Sensor">Dodgers Loop Sensor',
#  'atasets/Poker+Hand"><img border="1" src="assets/MLimages/SmallLarge158.jpg"/>',
#  'atasets/Poker+Hand">Poker Hand',
#  'atasets/MAGIC+Gamma+Telescope"><img border="1" src="assets/MLimages/SmallLarge159.jpg"/>',
#  'atasets/MAGIC+Gamma+Telescope">MAGIC Gamma Telescope',
#  'atasets/UJI+Pen+Characters"><img border="1" src="assets/MLimages/SmallLarge160.jpg"/>',
#  'atasets/UJI+Pen+Characters">UJI Pen Characters',
#  'atasets/Mammographic+Mass"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Mammographic+Mass">Mammographic Mass',
#  'atasets/Forest+Fires"><img border="1" src="assets/MLimages/SmallLarge162.jpg"/>',
#  'atasets/Forest+Fires">Forest Fires',
#  'atasets/Reuters+Transcribed+Subset"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Reuters+Transcribed+Subset">Reuters Transcribed Subset',
#  'atasets/Bag+of+Words"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Bag+of+Words">Bag of Words',
#  'atasets/Concrete+Compressive+Strength"><img border="1" src="assets/MLimages/SmallLarge165.jpg"/>',
#  'atasets/Concrete+Compressive+Strength">Concrete Compressive Strength',
#  'atasets/Hill-Valley"><img border="1" src="assets/MLimages/SmallLarge166.jpg"/>',
#  'atasets/Hill-Valley">Hill-Valley',
#  'atasets/Arcene"><img border="1" src="assets/MLimages/SmallLarge167.jpg"/>',
#  'atasets/Arcene">Arcene',
#  'atasets/Dexter"><img border="1" src="assets/MLimages/SmallLarge168.jpg"/>',
#  'atasets/Dexter">Dexter',
#  'atasets/Dorothea"><img border="1" src="assets/MLimages/SmallLarge169.jpg"/>',
#  'atasets/Dorothea">Dorothea',
#  'atasets/Gisette"><img border="1" src="assets/MLimages/SmallLarge170.jpg"/>',
#  'atasets/Gisette">Gisette',
#  'atasets/Madelon"><img border="1" src="assets/MLimages/SmallLarge171.jpg"/>',
#  'atasets/Madelon">Madelon',
#  'atasets/Ozone+Level+Detection"><img border="1" src="assets/MLimages/SmallLarge172.jpg"/>',
#  'atasets/Ozone+Level+Detection">Ozone Level Detection',
#  'atasets/Abscisic+Acid+Signaling+Network"><img border="1" src="assets/MLimages/SmallLargedefault.jpg"/>',
#  'atasets/Abscisic+Acid+Signaling+Network">Abscisic Acid Signaling Network',
#  'atasets/Parkinsons"><img border="1" src="assets/MLimages/SmallLarge174.jpg"/>',
#  'atasets/Parkinsons">Parkinsons',
#  'atasets/Character+Trajectories"><img border="1" src="assets/MLimages/SmallLarge175.jpg"/>',
#  'atasets/Character+Trajectories">Character Trajectories',
#  'atasets/Blood+Transfusion+Service+Center"><img border="1" src="assets/MLimages/SmallLarge176.jpg"/>',
#  'atasets/Blood+Transfusion+Service+Center">Blood Transfusion Service Center',
#  'atasets/UJI+Pen+Characters+%28Version+2%29"><img border="1" src="assets/MLimages/SmallLarge160.jpg"/>',
#  'atasets/UJI+Pen+Characters+%28Version+2%29">UJI Pen Characters (Version 2)',
#  'atasets/Semeion+Handwritten+Digit"><img border="1" src="assets/MLimages/SmallLarge178.jpg"/>',
#  'atasets/Semeion+Handwritten+Digit">Semeion Handwritten Digit',
#  'atasets/SECOM"><img border="1" src="assets/MLimages/SmallLarge179.jpg"/>',
#  'atasets/SECOM">SECOM',
#  'atasets/Plants"><img border="1" src="assets/MLimages/SmallLarge180.jpg"/>',
#  'atasets/Plants">Plants',
#  'atasets/Libras+Movement"><img border="1" src="assets/MLimages/SmallLarge181.jpg"/>',
#  'atasets/Libras+Movement">Libras Movement',
#  'atasets/Concrete+Slump+Test"><img border="1" src="assets/MLimages/SmallLarge165.jpg"/>',
#  'atasets/Concrete+Slump+Test">Concrete Slump Test',
#  'atasets/Communities+and+Crime"><img border="1" src="assets/MLimages/SmallLarge183.jpg"/>',
#  'atasets/Communities+and+Crime">Communities and Crime',
#  'atasets/Acute+Inflammations"><img border="1" src="assets/MLimages/SmallLarge184.jpg"/>',
#  'atasets/Acute+Inflammations">Acute Inflammations',
#  'atasets/Wine+Quality"><img border="1" src="assets/MLimages/SmallLarge186.jpg"/>',
#  'atasets/Wine+Quality">Wine Quality',
#  'atasets/URL+Reputation"><img border="1" src="assets/MLimages/SmallLarge187.jpg"/>',
#  'atasets/URL+Reputation">URL Reputation',
#  'atasets/p53+Mutants"><img border="1" src="assets/MLimages/SmallLarge188.jpg"/>',
#  'atasets/p53+Mutants">p53 Mutants',
#  'atasets/Parkinsons+Telemonitoring"><img border="1" src="assets/MLimages/SmallLarge174.jpg"/>',
#  'atasets/Parkinsons+Telemonitoring">Parkinsons Telemonitoring']

# %%
# el pandas Dataframe, debe darme asi de acuerdo a estos parametros:
Nombre de la base de datos
Link a la base de datos
Tipo de datos
Tipo de tarea a resolver (default task)
Tipo de las variables
Número de observaciones
Número de variables
Año
Descripción de la base:

# %%
import pandas as pd
df1=pd.DataFrame({"Nombre": name})
df2=pd.DataFrame({"link": links})
df3=pd.DataFrame({"tipo": typedata})
df4=pd.DataFrame({"homework": defaultask})
df5=pd.DataFrame({"variable": variables})
df6=pd.DataFrame({"numvariable": numvariables})
df7=pd.DataFrame({"año": years})
df8=pd.DataFrame({"description": descripcion})

# %%
table_Data=pd.concat([df1,df2,df3,df4,df5,df6,df7,df8], ignore_index=False, axis=1)
table_Data

# %%
#como resultado debe dar una tabla con los parametros encontrados

# %% [markdown]
# -----
